# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D as ax
import mpl_toolkits.mplot3d as p3d
from sklearn.manifold import Isomap

# %%
data = pd.read_excel("swiss roll.xls", header=None, names=["x1", "x2", "x3"])
data
# Out:
#            x1         x2         x3
# 0    2.560237   6.031287   7.055756
# 1   -6.198659   6.760549  -8.293126
# 2    6.083773   3.263753  -0.855010
# 3   -7.285543   8.140926   4.980369
# 4    0.576174  18.810396  -4.797441
# ..        ...        ...        ...
# 995 -2.468672   8.970690   7.778957
# 996  5.360720  19.327238 -10.153048
# 997  6.200446  11.088255  -0.423926
# 998  3.610184  18.287527   6.390499
# 999 -2.194365   7.409027 -10.565317
#
# [1000 rows x 3 columns]

# %%
X = data.values
X
# Out:
# array([[  2.56023663,   6.03128713,   7.05575645],
#        [ -6.19865897,   6.76054875,  -8.29312609],
#        [  6.08377267,   3.26375269,  -0.85501042],
#        ...,
#        [  6.20044632,  11.08825534,  -0.42392565],
#        [  3.61018413,  18.28752744,   6.39049874],
#        [ -2.19436474,   7.40902702, -10.56531714]])

# %%
isomap = Isomap(n_components=2, n_neighbors=5)
data_2d = isomap.fit_transform(X)
geo_distance_metrix = isomap.dist_matrix_

# %%
geo_distance_metrix
# Out:
# array([[ 0.        , 28.82145576, 10.94861035, ..., 12.70355702,
#         14.87444576, 33.52735407],
#        [28.82145576,  0.        , 39.15582924, ..., 39.84987925,
#         33.17301512,  4.70589832],
#        [10.94861035, 39.15582924,  0.        , ...,  9.30696908,
#         19.94272535, 43.86172755],
#        ...,
#        [12.70355702, 39.84987925,  9.30696908, ...,  0.        ,
#         12.24294029, 44.55577757],
#        [14.87444576, 33.17301512, 19.94272535, ..., 12.24294029,
#          0.        , 37.87891343],
#        [33.52735407,  4.70589832, 43.86172755, ..., 44.55577757,
#         37.87891343,  0.        ]])

# %%
plt.scatter(data_2d[:, 0], data_2d[:, 1])

# %%
fig = plt.figure(figsize=(16, 8))
ax = p3d.Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)
ax.scatter(X[:, 0], X[:, 1], X[:, 2])
plt.show()
